# %% [markdown]
# # 히스토그램
#  - 수치형 변수를 시각화할때 가장 많이 쓰는 방법이 히스토그램입니다.
#  - 히스토그램은 표로 되어 있는 도수 분포를 정보 그림으로 나타내는 것을 말합니다. 도수분포표를 그래프로 나타내는것을 뜻합니다.
#  - 보통 히스토그램에서는 가로축이 계급, 세로축이 도수를 뜻하는데 때로는 반대로 그리기도 합니다.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("D:\\GitRepository\\StudyPythonBigData\\resources\\bd_kma_weather.csv")

# %%
# os에 따라 시각화 폰트 설정하기
import os

if os.name == 'nt':
    font_family = "Malgun Gothic"
else:
    font_family = "AppleGothic"
sns.set(font=font_family, rc={"axes.unicode_minus" : False })

# %%
# retina 를 지원하는 디스플레이에서 폰트가 선명하게 보이기 위함
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
# 전체 수치 변수에 대한 히스토그램

h = df.hist(figsize=(24, 24))
