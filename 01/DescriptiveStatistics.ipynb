# %% [markdown]
# # 기술통계
# - 기술통계(descriptive statistics) - 측정이나 실험에서 수집한 자료의 정리, 표현, 요약, 해석 등을 통해 자료의 특성을 규명하는 통계적 방법
# - count(빈도수), mean(평균), std(표준편차), min(최솟값), max(최댓값), 25%(1사분위수), 50%(2사분위수, 중앙값), 75%(3사분위수)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
matplotlib.font_manager._rebuild()

# %%
df = pd.read_csv("D:\\GitRepository\\StudyPythonBigData\\resources\\bd_kma_weather.csv")
df
# Out:
#        지점 지점명          일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  \
# 0     108  서울  2017-01-01       2.7      -1.6          540.0       6.9
# 1     108  서울  2017-01-02       5.0       1.8         2355.0       9.2
# 2     108  서울  2017-01-03       2.0      -2.3          731.0       7.7
# 3     108  서울  2017-01-04       3.9       1.0            1.0       8.9
# 4     108  서울  2017-01-05       3.8      -0.1          316.0       7.3
# ...   ...  ..         ...       ...       ...            ...       ...
# 7660  159  부산  2019-12-27       3.6       0.4          719.0       9.0
# 7661  159  부산  2019-12-28       4.1      -0.3          736.0       9.4
# 7662  159  부산  2019-12-29       6.5       2.6          403.0       9.5
# 7663  159  부산  2019-12-30       9.6       7.1         2359.0      14.0
# 7664  159  부산  2019-12-31       0.1      -2.5         2357.0       7.1
#
#       최고기온 시각(hhmi)  강수 계속시간(hr)  10분 최다 강수량(mm)  ...  1.0m 지중온도(°C)  \
# 0            1419.0          NaN             NaN  ...            7.1
# 1            1355.0         2.08             NaN  ...            7.0
# 2            1444.0          NaN             NaN  ...            6.9
# 3            1519.0          NaN             NaN  ...            6.9
# 4            1444.0          NaN             NaN  ...            6.9
# ...             ...          ...             ...  ...            ...
# 7660         1437.0          NaN             NaN  ...           12.8
# 7661         1408.0          NaN             NaN  ...           12.8
# 7662         1438.0         8.00             NaN  ...           12.6
# 7663         1421.0         1.50             NaN  ...           12.6
# 7664            1.0          NaN             NaN  ...           12.3
#
#       1.5m 지중온도(°C)  3.0m 지중온도(°C)  5.0m 지중온도(°C)  합계 대형증발량(mm)  합계 소형증발량(mm)  \
# 0              10.2           15.7           17.5           0.7           1.0
# 1              10.1           15.6           17.5           0.9           1.2
# 2               9.9           15.5           17.4           1.3           1.8
# 3               9.8           15.4           17.4           1.5           2.2
# 4               9.7           15.4           17.4           1.6           2.3
# ...             ...            ...            ...           ...           ...
# 7660           15.3           18.6           19.3           2.5           3.6
# 7661           15.1           18.6           19.4           2.2           3.2
# 7662           14.9           18.6           19.3           0.6           0.8
# 7663           14.9           18.5           19.2           1.8           2.6
# 7664           14.8           18.5           19.4           2.4           3.4
#
#       9-9강수(mm)  안개 계속시간(hr)  합계 일조시간(hr)  합계 일사량(MJ/m2)
# 0           0.3          NaN          NaN            NaN
# 1           NaN          NaN          NaN            NaN
# 2           NaN          NaN          NaN            NaN
# 3           NaN          NaN          NaN            NaN
# 4           NaN          NaN          NaN            NaN
# ...         ...          ...          ...            ...
# 7660        NaN          NaN          9.2          12.64
# 7661        NaN          NaN          9.2          12.12
# 7662       12.8          NaN          0.0           2.66
# 7663        NaN          NaN          6.7           9.97
# 7664        NaN          NaN          9.3          13.09
#
# [7665 rows x 62 columns]

# %%
df.describe()
# Out:
#                 지점     평균기온(°C)     최저기온(°C)  최저기온 시각(hhmi)     최고기온(°C)  \
# count  7665.000000  7664.000000  7665.000000    7665.000000  7664.000000
# mean    137.571429    14.138374     9.984136     898.447880    19.034473
# std      19.220717     9.811973    10.130326     737.642143     9.847690
# min     108.000000   -14.800000   -17.800000       1.000000   -11.900000
# 25%     112.000000     6.000000     1.300000     510.000000    11.000000
# 50%     143.000000    15.200000    10.500000     618.000000    20.400000
# 75%     156.000000    22.400000    18.600000     745.000000    27.200000
# max     159.000000    33.700000    30.300000    2400.000000    39.600000
#
#        최고기온 시각(hhmi)  강수 계속시간(hr)  10분 최다 강수량(mm)  10분 최다강수량 시각(hhmi)  \
# count    7664.000000  2748.000000     1770.000000         1166.000000
# mean     1347.208768     5.407416        1.812599         1104.201544
# std       346.450789     5.262508        3.044922          741.338202
# min         1.000000     0.030000        0.000000        -2357.000000
# 25%      1315.000000     1.250000        0.100000          431.500000
# 50%      1428.000000     3.600000        0.600000         1050.000000
# 75%      1520.000000     8.170000        2.000000         1744.000000
# max      2400.000000    24.000000       25.500000         2356.000000
#
#        1시간 최다강수량(mm)  ...  1.0m 지중온도(°C)  1.5m 지중온도(°C)  3.0m 지중온도(°C)  \
# count    1770.000000  ...    4378.000000    4378.000000    4377.000000
# mean        4.592825  ...      15.702604      15.894678      16.118026
# std         8.291521  ...       7.294569       6.128202       3.808364
# min         0.000000  ...       2.200000       3.800000       7.600000
# 25%         0.100000  ...       9.200000      10.625000      13.000000
# 50%         1.400000  ...      16.200000      16.200000      16.100000
# 75%         5.300000  ...      22.400000      21.600000      19.600000
# max        86.300000  ...      29.100000      27.100000      24.700000
#
#        5.0m 지중온도(°C)  합계 대형증발량(mm)  합계 소형증발량(mm)    9-9강수(mm)  안개 계속시간(hr)  \
# count    4374.000000   6481.000000   6493.000000  1575.000000   315.000000
# mean       16.156013      2.839485      4.052580     9.245333     2.854984
# std         2.125400      1.567394      2.239275    19.301709     2.845048
# min        11.300000      0.200000      0.300000     0.000000     0.070000
# 25%        14.600000      1.600000      2.200000     0.000000     0.700000
# 50%        16.300000      2.500000      3.600000     1.500000     1.780000
# 75%        17.800000      4.000000      5.700000     8.400000     3.995000
# max        20.100000      9.200000     13.100000   180.700000    13.600000
#
#        합계 일조시간(hr)  합계 일사량(MJ/m2)
# count  2551.000000    2185.000000
# mean      6.945159      14.965492
# std       3.970528       7.254231
# min       0.000000       0.000000
# 25%       3.600000       9.800000
# 50%       8.100000      14.070000
# 75%       9.900000      20.790000
# max      14.100000      32.240000
#
# [8 rows x 60 columns]

# %%
df.groupby("지점명")["평균기온(°C)"].describe() # 지점명으로 그룹핑한 평균기온에 대한 기술통계치
# Out:
#       count       mean        std   min    25%   50%    75%   max
# 지점명
# 광주   1095.0  14.694795   9.542624  -8.0  6.500  15.6  23.00  32.0
# 대구   1094.0  14.498903   9.837044  -9.4  5.725  15.4  22.70  33.1
# 대전   1095.0  13.708767  10.379050 -11.8  4.700  14.6  22.55  33.4
# 부산   1095.0  15.373699   8.350203  -6.7  8.550  16.2  22.20  31.7
# 서울   1095.0  13.224840  10.894164 -14.8  3.900  14.6  22.70  33.7
# 울산   1095.0  14.656530   8.833875  -8.2  7.200  15.6  21.90  31.8
# 인천   1095.0  12.811416  10.365030 -14.6  4.000  14.0  21.90  31.8

# %%
#전체 평균기온의 기술통계치
temp = df["평균기온(°C)"].describe()
temp
# Out:
# count    7664.000000
# mean       14.138374
# std         9.811973
# min       -14.800000
# 25%         6.000000
# 50%        15.200000
# 75%        22.400000
# max        33.700000
# Name: 평균기온(°C), dtype: float64

# %%
IQR = temp["75%"] - temp["25%"]
max_outlier_base = temp["75%"] + (1.5 * IQR)
min_outlier_base = temp["25%"] - (1.5 * IQR)

print(f"{round(max_outlier_base)} 값보다 크면 이상치로 처리됩니다.")
print(f"{round(min_outlier_base)} 값보다 작으면 이상치로 처리됩니다.")
# Out:
# 47 값보다 크면 이상치로 처리됩니다.
# -19 값보다 작으면 이상치로 처리됩니다.

# %%
# matplotlib.pyplot 과 seaborn 을 사용하여 그래프 작업

plt.figure(figsize=(15, 2))
plt.title("평균기온의 상자수염그림")
g = sns.boxplot(data=df, x="평균기온(°C)")
# Out:
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 50684 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 47548 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50684 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50684 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47548 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 범주형 데이터의 기술통계 구하기

# %%
df.describe(include="object")
# Out:
#          지점명          일시
# count   7665        7665
# unique     7        1095
# top       인천  2018-05-08
# freq    1095           7

# %%
# 데이터 전체 요약정보

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7665 entries, 0 to 7664
# Data columns (total 62 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   지점                   7665 non-null   int64
#  1   지점명                  7665 non-null   object
#  2   일시                   7665 non-null   object
#  3   평균기온(°C)             7664 non-null   float64
#  4   최저기온(°C)             7665 non-null   float64
#  5   최저기온 시각(hhmi)        7665 non-null   float64
#  6   최고기온(°C)             7664 non-null   float64
#  7   최고기온 시각(hhmi)        7664 non-null   float64
#  8   강수 계속시간(hr)          2748 non-null   float64
#  9   10분 최다 강수량(mm)       1770 non-null   float64
#  10  10분 최다강수량 시각(hhmi)   1166 non-null   float64
#  11  1시간 최다강수량(mm)        1770 non-null   float64
#  12  1시간 최다 강수량 시각(hhmi)  1208 non-null   float64
#  13  일강수량(mm)             2753 non-null   float64
#  14  최대 순간 풍속(m/s)        7662 non-null   float64
#  15  최대 순간 풍속 풍향(16방위)    7662 non-null   float64
#  16  최대 순간풍속 시각(hhmi)     7662 non-null   float64
#  17  최대 풍속(m/s)           7662 non-null   float64
#  18  최대 풍속 풍향(16방위)       7662 non-null   float64
#  19  최대 풍속 시각(hhmi)       7662 non-null   float64
#  20  평균 풍속(m/s)           7657 non-null   float64
#  21  풍정합(100m)            7657 non-null   float64
#  22  평균 이슬점온도(°C)         7664 non-null   float64
#  23  최소 상대습도(%)           7664 non-null   float64
#  24  최소 상대습도 시각(hhmi)     7664 non-null   float64
#  25  평균 상대습도(%)           7665 non-null   float64
#  26  평균 증기압(hPa)          7665 non-null   float64
#  27  평균 현지기압(hPa)         7665 non-null   float64
#  28  최고 해면기압(hPa)         7664 non-null   float64
#  29  최고 해면기압 시각(hhmi)     7665 non-null   int64
#  30  최저 해면기압(hPa)         7663 non-null   float64
#  31  최저 해면기압 시각(hhmi)     7664 non-null   float64
#  32  평균 해면기압(hPa)         7665 non-null   float64
#  33  가조시간(hr)             7664 non-null   float64
#  34  합계 일조 시간(hr)         5092 non-null   float64
#  35  1시간 최다일사 시각(hhmi)    6486 non-null   float64
#  36  1시간 최다일사량(MJ/m2)     6486 non-null   float64
#  37  합계 일사(MJ/m2)         4298 non-null   float64
#  38  일 최심신적설(cm)          144 non-null    float64
#  39  일 최심신적설 시각(hhmi)     139 non-null    float64
#  40  일 최심적설(cm)           200 non-null    float64
#  41  일 최심적설 시각(hhmi)      194 non-null    float64
#  42  합계 3시간 신적설(cm)       143 non-null    float64
#  43  평균 전운량(1/10)         7665 non-null   float64
#  44  평균 중하층운량(1/10)       7665 non-null   float64
#  45  평균 지면온도(°C)          7664 non-null   float64
#  46  최저 초상온도(°C)          7664 non-null   float64
#  47  평균 5cm 지중온도(°C)      4363 non-null   float64
#  48  평균 10cm 지중온도(°C)     4372 non-null   float64
#  49  평균 20cm 지중온도(°C)     4363 non-null   float64
#  50  평균 30cm 지중온도(°C)     4373 non-null   float64
#  51  0.5m 지중온도(°C)        4374 non-null   float64
#  52  1.0m 지중온도(°C)        4378 non-null   float64
#  53  1.5m 지중온도(°C)        4378 non-null   float64
#  54  3.0m 지중온도(°C)        4377 non-null   float64
#  55  5.0m 지중온도(°C)        4374 non-null   float64
#  56  합계 대형증발량(mm)         6481 non-null   float64
#  57  합계 소형증발량(mm)         6493 non-null   float64
#  58  9-9강수(mm)            1575 non-null   float64
#  59  안개 계속시간(hr)          315 non-null    float64
#  60  합계 일조시간(hr)          2551 non-null   float64
#  61  합계 일사량(MJ/m2)        2185 non-null   float64
# dtypes: float64(58), int64(2), object(2)
# memory usage: 3.6+ MB

# %% [markdown]
# # 결측치 확인과 보간

# %%
df_null = df.isnull()

df_null.head()
# Out:
#       지점    지점명     일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  \
# 0  False  False  False     False     False          False     False
# 1  False  False  False     False     False          False     False
# 2  False  False  False     False     False          False     False
# 3  False  False  False     False     False          False     False
# 4  False  False  False     False     False          False     False
#
#    최고기온 시각(hhmi)  강수 계속시간(hr)  10분 최다 강수량(mm)  ...  1.0m 지중온도(°C)  \
# 0          False         True            True  ...          False
# 1          False        False            True  ...          False
# 2          False         True            True  ...          False
# 3          False         True            True  ...          False
# 4          False         True            True  ...          False
#
#    1.5m 지중온도(°C)  3.0m 지중온도(°C)  5.0m 지중온도(°C)  합계 대형증발량(mm)  합계 소형증발량(mm)  \
# 0          False          False          False         False         False
# 1          False          False          False         False         False
# 2          False          False          False         False         False
# 3          False          False          False         False         False
# 4          False          False          False         False         False
#
#    9-9강수(mm)  안개 계속시간(hr)  합계 일조시간(hr)  합계 일사량(MJ/m2)
# 0      False         True         True           True
# 1       True         True         True           True
# 2       True         True         True           True
# 3       True         True         True           True
# 4       True         True         True           True
#
# [5 rows x 62 columns]

# %%
# True 값을 더하면 결측치의 합이 됩니다.

df_null.sum().sort_values().tail(30).plot.barh(figsize=(10, 8))
# Out:
# <AxesSubplot:>
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 54633 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 54805 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51613 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 45796 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51312 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49549 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 50504 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49900 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54633 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54805 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51613 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45796 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50504 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54633 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54805 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51613 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45796 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51312 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49549 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50504 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\DEV\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df["일강수량(mm)"].fillna(method="ffill")
# Out:
# 0        NaN
# 1        0.3
# 2        0.3
# 3        0.3
# 4        0.3
#         ...
# 7660     1.7
# 7661     1.7
# 7662    11.4
# 7663     1.4
# 7664     1.4
# Name: 일강수량(mm), Length: 7665, dtype: float64

# %%
df["일강수량(mm)"].fillna(method="bfill")
# Out:
# 0        0.3
# 1        0.3
# 2        0.0
# 3        0.0
# 4        0.0
#         ...
# 7660    11.4
# 7661    11.4
# 7662    11.4
# 7663     1.4
# 7664     NaN
# Name: 일강수량(mm), Length: 7665, dtype: float64

# %% [markdown]
# ## 보간하기

# %%
df["일강수량(mm)"].interpolate(

    method='linear', limit_direction='both')
# Out:
# 0        0.300000
# 1        0.300000
# 2        0.250000
# 3        0.200000
# 4        0.150000
#           ...
# 7660     4.933333
# 7661     8.166667
# 7662    11.400000
# 7663     1.400000
# 7664     1.400000
# Name: 일강수량(mm), Length: 7665, dtype: float64

# %%
df["일강수량(mm)"].interpolate()
# Out:
# 0             NaN
# 1        0.300000
# 2        0.250000
# 3        0.200000
# 4        0.150000
#           ...
# 7660     4.933333
# 7661     8.166667
# 7662    11.400000
# 7663     1.400000
# 7664     1.400000
# Name: 일강수량(mm), Length: 7665, dtype: float64

# %%
df.isnull().sum()
# Out:
# 지점                  0
# 지점명                 0
# 일시                  0
# 평균기온(°C)            1
# 최저기온(°C)            0
#                  ...
# 합계 소형증발량(mm)     1172
# 9-9강수(mm)        6090
# 안개 계속시간(hr)      7350
# 합계 일조시간(hr)      5114
# 합계 일사량(MJ/m2)    5480
# Length: 62, dtype: int64
